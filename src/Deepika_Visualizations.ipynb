# %%
# Import Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
# Create a path to the csv and read it into a Pandas DataFrame
sleep_health_df = pd.read_csv('../Resources/cleaned_dataset.csv')
sleep_health_df.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder  Systolic  Diastolic
# 0         126/83          77         4200   No Diagnosis       126         83
# 1         125/80          75        10000   No Diagnosis       125         80
# 2         125/80          75        10000   No Diagnosis       125         80
# 3         140/90          85         3000    Sleep Apnea       140         90
# 4         140/90          85         3000    Sleep Apnea       140         90

# %%
sleep_health_df.columns
# Out:
# Index(['Person ID', 'Gender', 'Age', 'Occupation', 'Sleep Duration',
#        'Quality of Sleep', 'Physical Activity Level', 'Stress Level',
#        'BMI Category', 'Blood Pressure', 'Heart Rate', 'Daily Steps',
#        'Sleep Disorder', 'Systolic', 'Diastolic'],
#       dtype='object')

# %%
x_axis=sleep_health_df["Sleep Duration"]
y_axis=sleep_health_df["Stress Level"]
plt.bar(x_axis,y_axis)
plt.xlabel("Sleep Duration")
plt.ylabel("Stress Level")
plt.title("How sleep duration effecting stress levels")
plt.show()

# %%
male_df = sleep_health_df.loc[(sleep_health_df['Gender']=='Male')]
female_df = sleep_health_df.loc[(sleep_health_df['Gender']=='Female')]

# %%
# bar plot for df1
plt.bar(male_df['Sleep Duration'], male_df['Stress Level'], color='blue')

# bar plot for df2
plt.bar(female_df['Sleep Duration'], female_df['Stress Level'], color='red')

# Labels and title
plt.xlabel('Sleep Duration')
plt.ylabel('Stress Level')
plt.title('Bar chart with Two DataFrames')


# Display the plot
plt.show()

# %%
x_axis=sleep_health_df["Sleep Duration"]
y_axis=sleep_health_df["Stress Level"]
plt.scatter(x_axis,y_axis,color='b',marker='o',alpha=0.75)
plt.xlabel("Sleep Duration")
plt.ylabel("Stress Level")
plt.title("How sleep duration effecting stress levels")
plt.show()

# %%
# Scatter plot for df1
plt.scatter(male_df['Sleep Duration'], male_df['Stress Level'], label='Male Stress levels', color='blue',alpha=0.3)

# Scatter plot for df2
plt.scatter(female_df['Sleep Duration'], female_df['Stress Level'], label='Female stress levels', color='pink',alpha=0.9)

# Labels and title
plt.xlabel('Sleep Duration')
plt.ylabel('Stress Level')
plt.title('Sleep Duration vs Stress levels for Male & Female')

# Show legend
plt.legend()

# Display the plot
plt.show()

# %%
# Extract features and target variable from the combined dataset
X = sleep_health_df['Sleep Duration']
y = sleep_health_df['Stress Level']

# Create a linear regression model
model = LinearRegression()

# Fit the model
model.fit(X.values.reshape(-1, 1), y)

# Make predictions
y_pred = model.predict(X.values.reshape(-1, 1))

# Scatter plot for male
plt.scatter(male_df['Sleep Duration'], male_df['Stress Level'], label='Male Stress levels', color='blue', alpha=0.3)

# Scatter plot for female
plt.scatter(female_df['Sleep Duration'], female_df['Stress Level'], label='Female stress levels', color='pink', alpha=0.9)

# Plot the regression line using combined data
plt.plot(X, y_pred, color='red', label='Overall Linear Regression')

# Labels and title
plt.xlabel('Sleep Duration')
plt.ylabel('Stress Level')
plt.title('Sleep Duration Vs Stress Levels by gender')

# Display legend
plt.legend()

# Save an image
plt.savefig("../images/sleep_vs_stress_gender.png")
plt.show()

# %%
# Create separate linear regression models for male, female, and combined datasets
model_male = LinearRegression()
model_female = LinearRegression()
model_Overall = LinearRegression()

# Fit the models for male, female, and combined datasets
model_male.fit(X1.values.reshape(-1, 1), y1)
model_female.fit(X2.values.reshape(-1, 1), y2)
model_Overall.fit(X3.values.reshape(-1, 1), y3)

# Make predictions using the respective models
y1_pred = model_male.predict(X1.values.reshape(-1, 1))
y2_pred = model_female.predict(X2.values.reshape(-1, 1))
y3_pred = model_Overall.predict(X3.values.reshape(-1, 1))

# Scatter plot for overall
plt.scatter(sleep_health_df['Sleep Duration'], sleep_health_df['Stress Level'], label='Overall', color='pink', alpha=0.9)

# Plot the regression lines using separate models
plt.plot(X1, y1_pred, color='blue', label='Male Linear Regression')
plt.plot(X2, y2_pred, color='red', label='Female Linear Regression')
plt.plot(X3, y3_pred, color='purple', label='Overall Linear Regression')

# Labels and title
plt.xlabel('Sleep Duration')
plt.ylabel('Stress Level')
plt.title('Sleep Duration Vs Stress Levels')

# Display legend
plt.legend()

# Save the image
plt.savefig("../images/sleep_vs_stress.png")
plt.show()

# %%
stress_count_female=female_df['Stress Level'].unique()
stress_count_male=male_df['Stress Level'].unique()
stress_count_male
# Out:
# array([6, 8, 7, 3, 5, 4], dtype=int64)

# %%
# Create subplots for side-by-side histograms
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

# Histogram for Stress Level - Male
axs[0].hist(male_df['Stress Level'], bins=20, alpha=0.7, color='blue')
axs[0].set_xlabel('Stress Level')
axs[0].set_ylabel('Frequency')
axs[0].set_title('Distribution of Stress Level - Male')

# Histogram for Stress Level - Female
axs[1].hist(female_df['Stress Level'], bins=20, alpha=0.6, color='red')
axs[1].set_xlabel('Stress Level')
axs[1].set_ylabel('Frequency')
axs[1].set_title('Distribution of Stress Level - Female')

# Adjust layout
plt.tight_layout()

# Save image
plt.savefig('../images/stress_level_frequency.png')
plt.show()
