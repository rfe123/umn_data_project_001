# %%
# %matplotlib widget

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests
from pprint import pprint

# %%
sleep_health_df = pd.read_csv('../Resources/Sleep_health_and_lifestyle_dataset.csv')

sleep_health_df
# Out:
#      Person ID  Gender  Age            Occupation  Sleep Duration  \
# 0            1    Male   27     Software Engineer             6.1
# 1            2    Male   28                Doctor             6.2
# 2            3    Male   28                Doctor             6.2
# 3            4    Male   28  Sales Representative             5.9
# 4            5    Male   28  Sales Representative             5.9
# ..         ...     ...  ...                   ...             ...
# 369        370  Female   59                 Nurse             8.1
# 370        371  Female   59                 Nurse             8.0
# 371        372  Female   59                 Nurse             8.1
# 372        373  Female   59                 Nurse             8.1
# 373        374  Female   59                 Nurse             8.1
#
#      Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                   6                       42             6   Overweight
# ...

# %%
# cdc_url = 'https://data.cdc.gov/resource/hn4x-zwk7.json'

# response = requests.get(cdc_url).json()
# cdc_df = pd.DataFrame(response)

# %%
x_axis = 'Sleep Duration'
y_axis = 'Daily Steps'

sleep_health_df.plot.scatter(x_axis, y_axis)
plt.title(f"{x_axis} vs. {y_axis}")
plt.xlabel(x_axis)
plt.ylabel(y_axis)

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
x_axis = 'Sleep Duration'
y_axis = 'Quality of Sleep'

sleep_health_df.plot.scatter(x_axis, y_axis)
plt.title(f"{x_axis} vs. {y_axis}")
plt.xlabel(x_axis)
plt.ylabel(y_axis)

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
x_axis = 'Sleep Duration'
y_axis = 'Quality of Sleep'

male_df = sleep_health_df.loc[(sleep_health_df['Gender']=='Male')]
female_df = sleep_health_df.loc[(sleep_health_df['Gender']=='Female')]

plot1 = male_df.plot.scatter(x_axis, y_axis)
female_df.plot.scatter(x_axis, y_axis, color='red', ax=plot1)
plt.title(f"{x_axis} vs. {y_axis}")
plt.xlabel(x_axis)
plt.ylabel(y_axis)

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
x_axis = 'Stress Level'
y_axis = 'Quality of Sleep'

male_df = sleep_health_df.loc[(sleep_health_df['Gender']=='Male')]
female_df = sleep_health_df.loc[(sleep_health_df['Gender']=='Female')]

plot1 = male_df.plot.scatter(x_axis, y_axis)
female_df.plot.scatter(x_axis, y_axis, color='red', ax=plot1)
plt.title(f"{x_axis} vs. {y_axis}")
plt.xlabel(x_axis)
plt.ylabel(y_axis)

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
x_axis = 'Sleep Duration'
y_axis = 'Daily Steps'

plot2 = male_df.plot.scatter(x_axis, y_axis)
female_df.plot.scatter(x_axis, y_axis, color='red', ax=plot2)
plt.title(f"{x_axis} vs. {y_axis}")
plt.xlabel(x_axis)
plt.ylabel(y_axis)

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
y_axis = 'Stress Level'
x_axis = 'Blood Pressure'

sleep_health_df.sort_values('Blood Pressure').plot.scatter(x_axis, y_axis)

plt.title(f"{x_axis} vs. {y_axis}")
plt.xlabel(x_axis)
plt.ylabel(y_axis)
plt.xticks(rotation=45)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
sleep_health_df[['Systolic','Diastolic']] = sleep_health_df['Blood Pressure'].str.split('/', expand=True)
sleep_health_df.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder Systolic Diastolic
# 0         126/83          77         4200            NaN      126        83
# ...

# %%
y_axis = 'Stress Level'
x_axis = 'Systolic'

sleep_health_df.sort_values('Blood Pressure').plot.scatter(x_axis, y_axis)

plt.title(f"{x_axis} vs. {y_axis}")
plt.xlabel(x_axis)
plt.ylabel(y_axis)
plt.xticks(rotation=45)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
sleep_health_df.columns
# Out:
# Index(['Person ID', 'Gender', 'Age', 'Occupation', 'Sleep Duration',
#        'Quality of Sleep', 'Physical Activity Level', 'Stress Level',
#        'BMI Category', 'Blood Pressure', 'Heart Rate', 'Daily Steps',
#        'Sleep Disorder', 'Systolic', 'Diastolic'],
#       dtype='object')

# %%
bmi_categories = sleep_health_df['BMI Category'].unique()
bmi_categories
# Out:
# array(['Overweight', 'Normal', 'Obese', 'Normal Weight'], dtype=object)
