# %%
# %matplotlib widget

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests
from pprint import pprint

# %%
sleep_health_df = pd.read_csv('../Resources/cleaned_dataset.csv')

male_df = sleep_health_df.loc[(sleep_health_df['Gender']=='Male')]
female_df = sleep_health_df.loc[(sleep_health_df['Gender']=='Female')]

sleep_health_df.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder  Systolic  Diastolic
# 0         126/83          77         4200   No Diagnosis       126         83
# 1         125/80          75        10000   No Diagnosis       125         80
# 2         125/80          75        10000   No Diagnosis       125         80
# 3         140/90          85         3000    Sleep Apnea       140         90
# 4         140/90          85         3000    Sleep Apnea       140         90

# %%
occupations = sleep_health_df['Occupation'].unique()
bmi_categories = sleep_health_df['BMI Category'].unique()
sleep_disorders = sleep_health_df['Sleep Disorder'].unique()

# %%
sleep_disorder_groups = sleep_health_df.groupby('Sleep Disorder')['Person ID'].count()
sleep_disorder_groups

plot1 = sleep_disorder_groups.plot.pie()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# cdc_url = 'https://data.cdc.gov/resource/hn4x-zwk7.json'

# response = requests.get(cdc_url).json()
# cdc_df = pd.DataFrame(response)

# %%
x_axis = 'Sleep Duration'
y_axis = 'Daily Steps'

sleep_health_df.plot.scatter(x_axis, y_axis)
plt.title(f"{x_axis} vs. {y_axis}")
plt.xlabel(x_axis)
plt.ylabel(y_axis)

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
x_axis = 'Sleep Duration'
y_axis = 'Quality of Sleep'

sleep_health_df.plot.scatter(x_axis, y_axis)
plt.title(f"{x_axis} vs. {y_axis}")
plt.xlabel(x_axis)
plt.ylabel(y_axis)

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
x_axis = 'Sleep Duration'
y_axis = 'Quality of Sleep'

male_df = sleep_health_df.loc[(sleep_health_df['Gender']=='Male')]
female_df = sleep_health_df.loc[(sleep_health_df['Gender']=='Female')]

plot1 = male_df.plot.scatter(x_axis, y_axis)
female_df.plot.scatter(x_axis, y_axis, color='red', ax=plot1)
plt.title(f"{x_axis} vs. {y_axis}")
plt.xlabel(x_axis)
plt.ylabel(y_axis)

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
x_axis = 'Stress Level'
y_axis = 'Quality of Sleep'

plot1 = male_df.plot.scatter(x_axis, y_axis)
female_df.plot.scatter(x_axis, y_axis, color='red', ax=plot1)
plt.title(f"{x_axis} vs. {y_axis}")
plt.xlabel(x_axis)
plt.ylabel(y_axis)

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
x_axis = 'Sleep Duration'
y_axis = 'Daily Steps'

plot2 = male_df.plot.scatter(x_axis, y_axis)
female_df.plot.scatter(x_axis, y_axis, color='red', ax=plot2)
plt.title(f"{x_axis} vs. {y_axis}")
plt.xlabel(x_axis)
plt.ylabel(y_axis)

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
y_axis = 'Stress Level'
x_axis = 'Systolic'

plot2 = male_df.plot.scatter(x_axis, y_axis)
female_df.plot.scatter(x_axis, y_axis, color='red', ax=plot2)
plt.title(f"{x_axis} vs. {y_axis}")
plt.xlabel(x_axis)
plt.ylabel(y_axis)
plt.xticks(rotation=45)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
y_axis = 'Stress Level'
x_axis = 'Diastolic'

plot2 = male_df.plot.scatter(x_axis, y_axis)
female_df.plot.scatter(x_axis, y_axis, color='red', ax=plot2)
plt.title(f"{x_axis} vs. {y_axis}")
plt.xlabel(x_axis)
plt.ylabel(y_axis)
plt.xticks(rotation=45)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
sleep_health_df.columns
# Out:
# Index(['Person ID', 'Gender', 'Age', 'Occupation', 'Sleep Duration',
#        'Quality of Sleep', 'Physical Activity Level', 'Stress Level',
#        'BMI Category', 'Blood Pressure', 'Heart Rate', 'Daily Steps',
#        'Sleep Disorder', 'Systolic', 'Diastolic'],
#       dtype='object')

# %%
bmi_categories = sleep_health_df['BMI Category'].unique()
bins = [x for x in bmi_categories]

groups_df = sleep_health_df.groupby(['BMI Category','Gender'])
groups_df[['Sleep Duration', 'Quality of Sleep', 'Stress Level', 'Heart Rate', 'Daily Steps','Systolic', 'Diastolic']].mean().round(2)
# Out:
#                       Sleep Duration  Quality of Sleep  Stress Level  \
# BMI Category  Gender
# Normal        Female            7.79              8.50          3.50
#               Male              7.20              7.25          5.92
# Normal Weight Female            7.29              7.29          5.14
#               Male              7.43              7.71          5.29
# Obese         Female            7.40              7.00          5.00
#               Male              6.91              6.33          5.78
# Overweight    Female            6.88              7.22          5.32
#               Male              6.49              6.10          6.76
#
#                       Heart Rate  Daily Steps  Systolic  Diastolic
# BMI Category  Gender
# Normal        Female       66.50      6000.00    120.00      77.50
#               Male         69.82      7320.61    125.69      82.21
# Normal Weight Female       72.29      6578.57    122.71      80.64
#               Male         69.29      7142.86    119.43      78.71
# Obese         Female       84.00      3300.00    135.00      88.00
#               Male         84.33      3355.56    139.67      90.44
# Overweight    Female       70.39      7416.04    137.30      92.38
#               Male         72.36      5828.57    129.38      84.64
